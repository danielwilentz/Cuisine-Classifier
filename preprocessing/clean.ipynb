# %% [markdown]
# # Clean r/foodporn Posts

# %%
# Imports

import numpy as np
import pandas as pd
import re 
import string
from googletrans import Translator
import nltk
from nltk.corpus import words, stopwords

# Setting options

pd.set_option('display.max_colwidth', -1)
nltk.download('stopwords')
nltk.download('words')

# Load stop words
stop_words = stopwords.words('english')
wordlist = words.words()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danielwilentz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/danielwilentz/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Read in data
df = pd.read_pickle('../scrape/data/posts.pkl')

# %%
df.shape
# Out:
# (46739, 1)

# %%
# Take a look!
df = df.rename(columns = {0: 'title'})
df.sample(20)
# Out:
#                                                                                                                  title
# 22624  [Home made] Finger Millet Porridge
# 19166  Let them eat cake!
# 39640  Pesto Pappardelle Recipe
# 46591  Lemon Poppy Seed Donuts (480p)
# 17840  "Celebration Cake" from Dandilion Chocolate in San Francisco
# 28201  The way he topped my burger
# 14043  First attempt at grilled skirt stake!
# 25358  Korean Fried Wings With Homemade Gochujang Sauce [837 x 837]
# 41000  Lamb chops with a caramel sauce, topped with nuts, with a side of broccoli and roasted potatoes
# 22705  I bought two mountains of meat... And combined them.
# 28883  Lobsters on the half-shell
# 3607   Thai Turkey Burgers with Peanut Sauce[579x389]
# 7717   Birthday NY strip [oc]
# 13729  Video of Townsville miner food challenge goes viral. He smashes down 3k of chicken parmigiana in 6 minutes.
# 36238  [I ate] A summer time madness at 11th Avenue
# 9977   Barbecue shrimp and grits [OC] [3264x2448]
# 41968  Butter seared Halibut, Cornbread purée, candy stripe beet and Brussels salad with a roasted shallot vinaigrette
# 13496  So I stopped for some In &amp; out burger for dinner
# 13199  [OC] Stornoway Black pudding and free range poached egg on English muffin
# 6931   Some good Hamburgers [OC]

# %%
# Structure analysis
num_words = df['title'].apply(lambda x: len(x.split()))
num_words_mean, num_words_std = np.mean(num_words), np.std(num_words)

# %%
print('Mean number of words per post: {} \n STD of words per post: {}'.format(num_words_mean, num_words_std))
# Out:
# Mean number of words per post: 8.77500588373735
#  STD of words per post: 6.085953651711066

# %% [markdown]
# # Define some cleaning functions

# %%
# Function for removing punctuation
def drop_punc(my_text):
    clean_text = re.sub('[%s]' % re.escape(string.punctuation), ' ', my_text)
    return clean_text

# %%
# Function for making all text lowercase
def lower(my_text):
    clean_text = my_text.lower()
    return clean_text

# %%
# Function for removing all numbers
def remove_numbers(my_text):
    clean_text = re.sub('\w*\d\w*', '', my_text)
    return clean_text

# %%
# Function for removing emojis
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
# Function for removing stop words
def remove_stop(my_text):
    text_list = my_text.split()
    return ' '.join([word for word in text_list if word not in stop_words])

# %%
# Function for stripping whitespace
def my_strip(my_text):
    try: return my_text.strip()
    except Exception as e: return None

# %%
# Curated list of additional stop-words for this project
my_stop_words = ['oc', 'amp', 'homemade', 'food', 'foodporn', 'v', 'x', 'recipe', 'best', 'il', 'ever',
                'time', 'attempt', 'first', 'ate', 'made', 'home', 'today', 'make', 'friend', 'local',
                'new', 'day', 'birthday', 'like', 'amazing', 'de', 'happy', 'year', 'plate', 'video', 
                'cooked', 'dish', 'house', 'os', 'tried', 'super', 'perfect', 'free', 'way', 'delicious', 
                'good', 'night', 'last', 'porn', 'eating', 'got', 'know']

# Function for removing my stop words
def remove_my_stop(my_text):
    text_list = my_text.split()
    return ' '.join([word for word in text_list if word not in my_stop_words])

# %% [markdown]
# ### Special function for removing posts that are ads:

# %%
# curated list for words pertaining to advertisements:
ad_words = ['coupon', 'coupons', 'promo', 'promos', 'code', 'https', 'http', 'com']
def catch_ads(my_text):
    text_list = my_text.split()
    ad = False
    for word in text_list:
        if word in ad_words:
            ad = True
            break
    if ad: return None
    else: return my_text

# %% [markdown]
# ### Special function for translating to english

# %%
# Function to translate into english
translator = Translator()
def translate(my_text):
    try:
        translated = translator.translate(my_text, dest='en')
        return translated.text
    except Exception as e:
        return my_text

# %% [markdown]
# The above function takes a long time to run on the full DataFrame.
#
# Alternatively, we can look into the nltk.corpus words of the english language to determine the language of a given post

# %%
# Function to detect english
def is_english(my_text):
    if my_text is None:
        return my_text
    text_list = my_text.split()
    english = 0
    non_english = 0
    for word in text_list:
        if word not in wordlist:
            non_english += 1
        else:
            english += 1
    if english > 0.25*non_english:
        return True
    else: return False

# %% [markdown]
# # Let's see how well our functions work!

# %%
test = df.sample(50)

# %%
for index, row in test.iterrows():
    text = row[0]
    print(text)
    cleaned = deEmojify(remove_numbers(drop_punc(lower(text))))
    print(cleaned)
    cleaned_no_punc = remove_my_stop(remove_stop(cleaned))
    print(cleaned_no_punc)
    no_ads = my_strip(catch_ads(cleaned_no_punc))
    print(no_ads)
    flag = is_english(no_ads)
    print(flag)
    print()
# Out:
# Yes please!
# yes please
# yes please
# yes please
# True
#
# I want to know how long it's been standard to take food photos from this very deliberate angle. I do it, you do it, and when someone does it with a 1' angle off, I get dizzy. What was the path of this photographic style and what has contributed to its success?
# i want to know how long it s been standard to take food photos from this very deliberate angle  i do it  you do it  and when someone does it with a   angle off  i get dizzy  what was the path of this photographic style and what has contributed to its success
# want long standard take photos deliberate angle someone angle get dizzy path photographic style contributed success
# want long standard take photos deliberate angle someone angle get dizzy path photographic style contributed success
# True
#
# Donuts thanksgiving Donuts t-shirt
# donuts thanksgiving donuts t shirt
# donuts thanksgiving donuts shirt
# donuts thanksgiving donuts shirt
# True
#
# Cinnamoroll Pop-up Cafe at Kumoya | Halal Certified Cafe With KAWAII Mains, Desserts and Drinks
# cinnamoroll pop up cafe at kumoya   halal certified cafe with kawaii mains  desserts and drinks
# cinnamoroll pop cafe kumoya halal certified cafe kawaii mains desserts drinks
# cinnamoroll pop cafe kumoya halal certified cafe kawaii mains desserts drinks
# True
#
# Did a casserole tonight. [OC] [2448 x 2448]
# did a casserole tonight   oc    x
# casserole tonight
# casserole tonight
# True
#
# 1/4 hotdog wrapped in bacon w/Mac & cheese, BBQ sauce[OC][4023X3024]
#   hotdog wrapped in bacon w mac   cheese  bbq sauce oc
# hotdog wrapped bacon w mac cheese bbq sauce
# hotdog wrapped bacon w mac cheese bbq sauce
# True
#
# I'm no professional chef, but I like trying to make new things in the kitchen. Today I tried my hand at pulled pork, and I can honestly say it's the best I've had.
# i m no professional chef  but i like trying to make new things in the kitchen  today i tried my hand at pulled pork  and i can honestly say it s the best i ve had
# professional chef trying things kitchen hand pulled pork honestly say
# professional chef trying things kitchen hand pulled pork honestly say
# True
#
# Please take this quick one minute survey.
# please take this quick one minute survey
# please take quick one minute survey
# please take quick one minute survey
# True
#
# When it's s snow day in New Jersey. Homemade porkroll, egg and cheese
# when it s s snow day in new jersey  homemade porkroll  egg and cheese
# snow jersey porkroll egg cheese
# snow jersey porkroll egg cheese
# True
#
# [oc] i ate this beautiful breakfast burrito the size of my thigh smothered in salsa at a diner in Vail
#  oc  i ate this beautiful breakfast burrito the size of my thigh smothered in salsa at a diner in vail
# beautiful breakfast burrito size thigh smothered salsa diner vail
# beautiful breakfast burrito size thigh smothered salsa diner vail
# True
#
# Shrimp, mushroom, and spinach pesto.
# shrimp  mushroom  and spinach pesto
# shrimp mushroom spinach pesto
# shrimp mushroom spinach pesto
# True
#
# Grilled swordfish, artichoke & oyster [OC][4032x3024]
# grilled swordfish  artichoke   oyster  oc
# grilled swordfish artichoke oyster
# grilled swordfish artichoke oyster
# True
#
# Pumpkin Macaroons
# pumpkin macaroons
# pumpkin macaroons
# pumpkin macaroons
# True
#
# Homemade beef brisket chilli dog on a brioche bun [OC]
# homemade beef brisket chilli dog on a brioche bun  oc
# beef brisket chilli dog brioche bun
# beef brisket chilli dog brioche bun
# True
#
# Lamb mixed with almonds
# lamb mixed with almonds
# lamb mixed almonds
# lamb mixed almonds
# True
#
# After a week-long cure, the bacon was ready for the smoker today
# after a week long cure  the bacon was ready for the smoker today
# week long cure bacon ready smoker
# week long cure bacon ready smoker
# True
#
# [OC] Mini New York Cheesecakes [960x720]
#  oc  mini new york cheesecakes
# mini york cheesecakes
# mini york cheesecakes
# True
#
# First homemade pizza and first post here. I'm just a student tryna cook better
# first homemade pizza and first post here  i m just a student tryna cook better
# pizza post student tryna cook better
# pizza post student tryna cook better
# True
#
# First time making burgers and fries. [OC] [1334 x 750]
# first time making burgers and fries   oc    x
# making burgers fries
# making burgers fries
# True
#
# Street Food - Uighur Kabobs - [OC] [2725x1835]
# street food   uighur kabobs    oc
# street uighur kabobs
# street uighur kabobs
# True
#
# Homemade Chocolate Brownies with a White Chocolate drizzle
# homemade chocolate brownies with a white chocolate drizzle
# chocolate brownies white chocolate drizzle
# chocolate brownies white chocolate drizzle
# True
#
# First Time Having Beef Ribs, and They Were Amazing - Terry Black's BBQ - Austin, TX[OC]
# first time having beef ribs  and they were amazing   terry black s bbq   austin  tx oc
# beef ribs terry black bbq austin tx
# beef ribs terry black bbq austin tx
# True
#
# OC- I singled out the bubble. It was delicious.
# oc  i singled out the bubble  it was delicious
# singled bubble
# singled bubble
# True
#
# My homemade mac &amp; cheese [1024x576]
# my homemade mac  amp  cheese
# mac cheese
# mac cheese
# True
#
# [OC] test run pumpkin rolls!
#  oc  test run pumpkin rolls
# test run pumpkin rolls
# test run pumpkin rolls
# True
#
# Baked hot and sticky Sriracha Honey chicken wings [OC][OS][1024x1024]
# baked hot and sticky sriracha honey chicken wings  oc  os
# baked hot sticky sriracha honey chicken wings
# baked hot sticky sriracha honey chicken wings
# True
#
# Assorted meat lovers spaghetti 🍝 [2020x1982]
# assorted meat lovers spaghetti
# assorted meat lovers spaghetti
# assorted meat lovers spaghetti
# True
#
# Mini taco de guisado sampler served on freshly made tortillas [4032x3024][OC]
# mini taco de guisado sampler served on freshly made tortillas    oc
# mini taco guisado sampler served freshly tortillas
# mini taco guisado sampler served freshly tortillas
# True
#
# [Homemade] Broiled lobster with herbs, butter, and lemon.
#  homemade  broiled lobster with herbs  butter  and lemon
# broiled lobster herbs butter lemon
# broiled lobster herbs butter lemon
# True
#
# Bone-in Cote de Boef - oven set to eventual internal temperature of the beef
# bone in cote de boef   oven set to eventual internal temperature of the beef
# bone cote boef oven set eventual internal temperature beef
# bone cote boef oven set eventual internal temperature beef
# True
#
# Home made cinnamon rolls.
# home made cinnamon rolls
# cinnamon rolls
# cinnamon rolls
# True
#
# Bacon Wrapped Guacamole Stuffed Chicken Recipe
# bacon wrapped guacamole stuffed chicken recipe
# bacon wrapped guacamole stuffed chicken
# bacon wrapped guacamole stuffed chicken
# True
#
# I baked a cheesecake (first time)
# i baked a cheesecake  first time
# baked cheesecake
# baked cheesecake
# True
#
# [OC] Buff-Chix Pizza [3024x4032]
#  oc  buff chix pizza
# buff chix pizza
# buff chix pizza
# True
#
# Homemade Cinnabon Copycat Rolls with Powdered Sugar Glaze [OC]
# homemade cinnabon copycat rolls with powdered sugar glaze  oc
# cinnabon copycat rolls powdered sugar glaze
# cinnabon copycat rolls powdered sugar glaze
# True
#
# trout, pumpkin purée and mustard sauce [560 × 550]
# trout  pumpkin pure and mustard sauce
# trout pumpkin pure mustard sauce
# trout pumpkin pure mustard sauce
# True
#
# (I ate) A beautiful bushel of Wisconsin Red Delicious Apples [4608x3456]
#  i ate  a beautiful bushel of wisconsin red delicious apples
# beautiful bushel wisconsin red apples
# beautiful bushel wisconsin red apples
# True
#
# France food lovers
# france food lovers
# france lovers
# france lovers
# False
#
# Double Soft Shell Crab BLT
# double soft shell crab blt
# double soft shell crab blt
# double soft shell crab blt
# True
#
# The best burger I've made thus far.
# the best burger i ve made thus far
# burger thus far
# burger thus far
# True
#
# Two way homemade icing sugar recipe । two way Bangladeshi icing sugar re...
# two way homemade icing sugar recipe  two way bangladeshi icing sugar re
# two icing sugar two bangladeshi icing sugar
# two icing sugar two bangladeshi icing sugar
# True
#
# Michelin starred streetfood! [1024x769]
# michelin starred streetfood
# michelin starred streetfood
# michelin starred streetfood
# True
#
# Royale Burger from Umami Burger [4032 x 3024]
# royale burger from umami burger   x
# royale burger umami burger
# royale burger umami burger
# True
#
# Last weeks NYE meal.
# last weeks nye meal
# weeks nye meal
# weeks nye meal
# True
#
# Martinis (Based on 2 oz. liquor) or Martini Classic
# martinis  based on  oz  liquor  or martini classic
# martinis based oz liquor martini classic
# martinis based oz liquor martini classic
# True
#
# Poached salmon wrapped in cucumber and dill lemon creme freiche with roasted tots [OC][900x900]
# poached salmon wrapped in cucumber and dill lemon creme freiche with roasted tots  oc
# poached salmon wrapped cucumber dill lemon creme freiche roasted tots
# poached salmon wrapped cucumber dill lemon creme freiche roasted tots
# True
#
# Valentines Day Dinner
# valentines day dinner
# valentines dinner
# valentines dinner
# True
#
# [Homemade] Andouille sausage gravy and biscuits
#  homemade  andouille sausage gravy and biscuits
# andouille sausage gravy biscuits
# andouille sausage gravy biscuits
# True
#
# Sexy Pasta [OC] [3120x4160]
# sexy pasta  oc
# sexy pasta
# sexy pasta
# True
#
# Sushi anyone?🍱🤗
# sushi anyone
# sushi anyone
# sushi anyone
# True

# %% [markdown]
# The cleaning looks good! Let's apply it to the whole dataframe:

# %%
df['cleaned_title'] = df['title'].apply(lower).apply(drop_punc).apply(remove_numbers).apply(deEmojify)
df['cleaned_title'] = df['cleaned_title'].apply(remove_stop).apply(remove_my_stop).apply(catch_ads)
df['cleaned_title'] = df['cleaned_title'].str.strip()

# %%
df.head(50)
# Out:
#                                                                                                             title  \
# 0   Bacon Lollipops from Bell's Eccentric Cafe in Grand Rapids, MI [OC] [2232x2232]
# 1   Pico de Gallo - Spend With Pennies
# 2   Our birthday dinner at Elizabeth's Chop House in Marquette MI
# 3   Artisanal mezcal the best way to celebrate Cinco de Mayo
# 4   Veggie + eggie = ... er, veggie
# 5   MONSTERS INC CUPCAKES - https://www.youtube.com/watch?v=QigrA_sSyeI
# 6   Teppanyaki Caramel Popcorn (X-Post From r/damnthatsinteresting)
# 7   I made my own ratatouille. Here it is before baking
# 8   Homemade Cookie
# 9   Chicken and broccoli stir fry [homemade{
# 10  Vietnamese chicken with rice noodles
# 11  Chaminichanga
# 12  مدحت الشريف..عدم حضور الوزراء للجان التخصصيه متعمد ..والرقم القومى هو قا...
# 13  Truffle pork ramen - from the only Michelin starred ramen restaurant in the world
# 14  Part of an 8 course I did. Rabbit tenderloin, braised rabbit legs, and rabbit jus.
# 15  Pan Seared Scallops! [3264px×2448]
# 16  ICYMI: FOOD: Easy Classic Toad in the Hole
# 17  Dipped orange puffs into hot caramel! Homemade Citrust Caramel Tart [OC] [600*600]
# 18  Just a super cool care bear cake (all is edible)
# 19  OREO mini cereal. Probably the best Idea I have had all week.
# 20  That's a full pot of gumbo.
# 21  Corn Fried Rice How To Make Corn Rice
# 22  I stole someone's thunder - Donut shaped Sushi
# 23  Hungarian Goulash on Spätzle [1840×1152] [OC]
# 24  Lean beef fajitas with the usual Tex-Mex fixings [OC] [1632x1224]
# 25  A while lot of good Persian food, can you name them all.
# 26  Queso Fundido del Mar from Ensenada
# 27  Halibut, Porcini cream, Broccolini, Cauliflower, Iberico, Crispy halibut skin, Bacon foam. [OC] [2432 × 4320]
# 28  Tuna Steak, Swordfish and Onigiri Kebabs with a rich nettle and hoisin drizzle :)
# 29  Friends and I made supplì with chili pesto [728x971]
# 30  Kob Woonsen (garlic and soy frog legs), Uncle Boons, NYC, 2016 Michelin star recipient
# 31  Grilled Shrimp, Chorizo, Potatoes, Saffron Aioli, Paired w/ New Belgium Hoppy Blonde
# 32  Chicken salad (500*500)
# 33  Pizza "Regina", Italy, Firenze
# 34  Literally. [609 x 353]
# 35  Butter Chicken Egg Rolls
# 36  Ask is the place to go
# 37  Shabu shabu with spicy miso broth at Little Dipper Hot Pot in Dublin, CA
# 38  3 Ways To Lose Belly Fat Even Without Working Out
# 39  Choco chip goodness
# 40  Monster cookie cheesecake (533*800)
# 41  First try at making cloud eggs.
# 42  Confit du canard w/potato [4032 × 2688]
# 43  Bhapa Ilish | Simple Recipe To Cook Hilsa Fish | Easy And Fast Recipe To Cook Sorse Ilish
# 44  Blueberry Muffin Flavored Granola [600-900]
# 45  Charcoal grilled Tawook (chicken skewers marinated in yogurt and garlic) [2048 X 1430]
# 46  Yellow Edge Grouper pan fried and then baked, stuffed with cilantro an jalapeno (4656x3492)
# 47  Sips, Sweets, &amp; Slices this weekend in Los Angeles
# 48  Making kebabs for dinner.
# 49  [OC] Foie Gras with rhubarb and ume shu gel. (4032x3024)
#
#                                                                           cleaned_title
# 0   bacon lollipops bell eccentric cafe grand rapids mi
# 1   pico gallo spend pennies
# 2   dinner elizabeth chop marquette mi
# 3   artisanal mezcal celebrate cinco mayo
# 4   veggie eggie er veggie
# 5   None
# 6   teppanyaki caramel popcorn post r damnthatsinteresting
# 7   ratatouille baking
# 8   cookie
# 9   chicken broccoli stir fry
# 10  vietnamese chicken rice noodles
# 11  chaminichanga
# 12
# 13  truffle pork ramen michelin starred ramen restaurant world
# 14  part course rabbit tenderloin braised rabbit legs rabbit jus
# 15  pan seared scallops
# 16  icymi easy classic toad hole
# 17  dipped orange puffs hot caramel citrust caramel tart
# 18  cool care bear cake edible
# 19  oreo mini cereal probably idea week
# 20  full pot gumbo
# 21  corn fried rice corn rice
# 22  stole someone thunder donut shaped sushi
# 23  hungarian goulash sptzle
# 24  lean beef fajitas usual tex mex fixings
# 25  lot persian name
# 26  queso fundido del mar ensenada
# 27  halibut porcini cream broccolini cauliflower iberico crispy halibut skin bacon foam
# 28  tuna steak swordfish onigiri kebabs rich nettle hoisin drizzle
# 29  friends suppl chili pesto
# 30  kob woonsen garlic soy frog legs uncle boons nyc michelin star recipient
# 31  grilled shrimp chorizo potatoes saffron aioli paired w belgium hoppy blonde
# 32  chicken salad
# 33  pizza regina italy firenze
# 34  literally
# 35  butter chicken egg rolls
# 36  ask place go
# 37  shabu shabu spicy miso broth little dipper hot pot dublin ca
# 38  ways lose belly fat even without working
# 39  choco chip goodness
# 40  monster cookie cheesecake
# 41  try making cloud eggs
# 42  confit du canard w potato
# 43  bhapa ilish simple cook hilsa fish easy fast cook sorse ilish
# 44  blueberry muffin flavored granola
# 45  charcoal grilled tawook chicken skewers marinated yogurt garlic
# 46  yellow edge grouper pan fried baked stuffed cilantro jalapeno
# 47  sips sweets slices weekend los angeles
# 48  making kebabs dinner
# 49  foie gras rhubarb ume shu gel

# %% [markdown]
# Now let's add a new column using the 'is_english' function to try to pick out which observations are in english and which aren't

# %%
df['in_english'] = df['cleaned_title'].apply(is_english)

# %%
df.sample(50)
# Out:
#                                                                                                                                                                       title  \
# 34471  Beef taco with black beans, cheddar cheese, and sour cream (and a brewski of course). [OC]
# 14959  Croissant Dragons
# 41837  Slow cooker Italian beef with sautéd mushrooms, roasted bell peppers, pepperoncini and provolone cheese, on a toasted hoagie [960x632] [OC]
# 36183  Chicken&Waffle Benedict! @Beachside Cafe in San Francisco. Delicious! [1440x1440]
# 2556   Lemon and garlic flavored green beans topped with crushed almonds. Baked chicken thighs and Mac and cheese.This is what I cooked for dinner tonight.
# 14768  I made a Rose Apple Pie for my friend's birthday!
# 1322   (homemade) carbonara, the way it's supposed to be
# 22032  Milk and Honey Dessert at The NoMad Restaurant, NYC! [OC]
# 33935  Chili's grill and bar[1280X1280]
# 11812  Corn flan with smoked tomatoes and zucchini with a chili oil and zucchini sauce. Art of the Table, Seattle WA. [OC] [1000x667]
# 1182   Jack in the Box burger on new year’s eve got me some commercial quality burger assembly (I have low standards)
# 425    Welcome to La Fiesta catering service/ caterer in kolkata
# 35867  Hara bhara kabab recipe
# 16367  Dulcey Panna Cotta
# 33635  Thai afternoon tea [1000 x 1000]
# 14078  Tripple cheese sandwitch
# 13318  "Field of Dreams" cake
# 24470  I Made Perfectly Chewy Chocolate Chip Cookies.
# 21529  Soup dumplings from Din Tai Fung
# 6749   Make ye-self a mini pie
# 11699  Double bacon corndog at MN state fair. [iphone6]
# 14044  Grilling Perfection
# 35277  We bought some random cured meat in Vienna airport
# 17905  I [ate] grilled chicken with dinosaur bbq sauce [3024X4032]
# 17440  My other post got pulled but here is a pic of our winning ribs out of 11 teams. 3 hours with rub, 2 hours tented in foil and 1 hour naked again to let them pull in.
# 23959  The Health Benefits Of Jute Or Salyut Leaves (Ewedu leaves) And How It Is Prepared In Nigeria
# 38349  Did anyone know that McDonalds sold Fried Chicken??
# 59     This margarita, The Barbie Dream House
# 4459   Gebäck mit Käse – Peynirli Katmer Poğaça - Türkische Gerichte
# 30740  Why does this hamburger bun have a nicer ass than me?
# 37612  Homemade Chicken Pot Pie
# 22371  Sauteed chicken breast with tomato pasta, julienned vegetables, and snap peas. [2688x1520]
# 30532  Toaster Oven Kale Burgers
# 1398   Made Ice Cream Sandwiches.
# 5513   My Almost-Chicago Dog [1920x1920]
# 37943  Yakimeshi (Fried Rice) in a heart shape. [1920 x 1080] [GIF]
# 12851  Frikadellen mit Soße – Soslu Köfte - Türkische Gerichte
# 16033  Asparagus, Egg and Prosciutto Breakfast Tarts
# 8152   Food Packaging Market– Growth, Future Prospects and Competitive Analysis and Forecast 2019
# 11611  Kartoffel mit Joghurt – Yoğurtlu Patates - Türkische Gerichte
# 12473  "Well, that's aesthetically pleasing" he said
# 14130  South Indian Style Fish Curry
# 42437  portrait mode on iPhone 7 plus. Practically magic.
# 18231  I made curried wild pigeon breasts and chunky raita salad
# 23774  My Delicious Chocolate Banana Dessert [5184x3456] [OC]
# 40451  BBQ Lamb Leg with Garlicky Sauce [800x1020] Recipe link in comments
# 37395  Soba
# 12949  Does this count (they are ends of carrots)?
# 3233   First ever attempt at a brisket
# 34841  [Homemade] Apple cider bacon with Canadian maple syrup, chopped ham, and beautifully sautéed onions all blended in a potato hash with a fried egg!
#
#                                                                                                     cleaned_title  \
# 34471  beef taco black beans cheddar cheese sour cream brewski course
# 14959  croissant dragons
# 41837  slow cooker italian beef sautd mushrooms roasted bell peppers pepperoncini provolone cheese toasted hoagie
# 36183  chicken waffle benedict beachside cafe san francisco
# 2556   lemon garlic flavored green beans topped crushed almonds baked chicken thighs mac cheese dinner tonight
# 14768  rose apple pie
# 1322   carbonara supposed
# 22032  milk honey dessert nomad restaurant nyc
# 33935  chili grill bar
# 11812  corn flan smoked tomatoes zucchini chili oil zucchini sauce art table seattle wa
# 1182   jack box burger years eve commercial quality burger assembly low standards
# 425    welcome la fiesta catering service caterer kolkata
# 35867  hara bhara kabab
# 16367  dulcey panna cotta
# 33635  thai afternoon tea
# 14078  tripple cheese sandwitch
# 13318  field dreams cake
# 24470  perfectly chewy chocolate chip cookies
# 21529  soup dumplings din tai fung
# 6749   ye self mini pie
# 11699  double bacon corndog mn state fair
# 14044  grilling perfection
# 35277  bought random cured meat vienna airport
# 17905  grilled chicken dinosaur bbq sauce
# 17440  post pulled pic winning ribs teams hours rub hours tented foil hour naked let pull
# 23959  health benefits jute salyut leaves ewedu leaves prepared nigeria
# 38349  anyone mcdonalds sold fried chicken
# 59     margarita barbie dream
# 4459   gebck mit kse peynirli katmer poaa trkische gerichte
# 30740  hamburger bun nicer ass
# 37612  chicken pot pie
# 22371  sauteed chicken breast tomato pasta julienned vegetables snap peas
# 30532  toaster oven kale burgers
# 1398   ice cream sandwiches
# 5513   almost chicago dog
# 37943  yakimeshi fried rice heart shape gif
# 12851  frikadellen mit soe soslu kfte trkische gerichte
# 16033  asparagus egg prosciutto breakfast tarts
# 8152   packaging market growth future prospects competitive analysis forecast
# 11611  kartoffel mit joghurt yourtlu patates trkische gerichte
# 12473  well aesthetically pleasing said
# 14130  south indian style fish curry
# 42437  portrait mode iphone plus practically magic
# 18231  curried wild pigeon breasts chunky raita salad
# 23774  chocolate banana dessert
# 40451  bbq lamb leg garlicky sauce link comments
# 37395  soba
# 12949  count ends carrots
# 3233   brisket
# 34841  apple cider bacon canadian maple syrup chopped ham beautifully sauted onions blended potato hash fried egg
#
#       in_english
# 34471  True
# 14959  False
# 41837  True
# 36183  True
# 2556   True
# 14768  True
# 1322   True
# 22032  True
# 33935  True
# 11812  True
# 1182   True
# 425    True
# 35867  True
# 16367  True
# 33635  True
# 14078  True
# 13318  True
# 24470  True
# 21529  True
# 6749   True
# 11699  True
# 14044  True
# 35277  True
# 17905  True
# 17440  True
# 23959  True
# 38349  True
# 59     True
# 4459   False
# 30740  True
# 37612  True
# 22371  True
# 30532  True
# 1398   True
# 5513   True
# 37943  True
# 12851  False
# 16033  True
# 8152   True
# 11611  False
# 12473  True
# 14130  True
# 42437  True
# 18231  True
# 23774  True
# 40451  True
# 37395  False
# 12949  True
# 3233   True
# 34841  True

# %%
# See how many data points will be lost

df['in_english'].value_counts()
# Out:
# True     42234
# False    4211
# Name: in_english, dtype: int64

# %% [markdown]
# I'm not too stoked on this translator. It seems to be getting some points wrong, so by using it as a filter, I will be losing potentially useful information.
#
# I may come back and revisit this step either with a stronger translator or by grabbing more data to compensate for the lost stuff.

# %%
df[df['in_english'] == False].sample(20)
# Out:
#                                                                    title  \
# 27693  PanicSupper
# 36537  A Clqassic [568 x 776]
# 5276   Amazing Seviche [1024x768]
# 24325  I4es
# 4588   [I Ate] Kyushu Danji Ramen at Terakawa Ramen in Philadelphia
# 42617  Porksicles
# 38656  NUTELLA[720x1280][OC]
# 9010   Steamed Eggs [3456 × 4608]
# 30778  The Ratatouille from "Ratatouille"
# 11463  #GARDENCATERING #Ct #Food #GoldenNuggets
# 6113   Tried from a YouTube video [5312x2988]
# 7785   [oc] home made fastfood
# 6797   Fart
# 523    Seatruck Ferries - Liverpool to Dublin
# 29222  Indian food
# 30715  Strappy taquería #CDMX #Tacos
# 11173  Tacos
# 3590   Gemüsen aus dem Ofen – Fırında Karışık Sebze - Türkische Gerichte
# 17792  Oreo Churros!!
# 36391  Türkische Fladen – Karışık Pideler - Türkische Gerichte
#
#                                                 cleaned_title in_english
# 27693  panicsupper                                             False
# 36537  clqassic                                                False
# 5276   seviche                                                 False
# 24325                                                          False
# 4588   kyushu danji ramen terakawa ramen philadelphia          False
# 42617  porksicles                                              False
# 38656  nutella                                                 False
# 9010   steamed eggs                                            False
# 30778  ratatouille ratatouille                                 False
# 11463  gardencatering ct goldennuggets                         False
# 6113   youtube                                                 False
# 7785   fastfood                                                False
# 6797   fart                                                    False
# 523    seatruck ferries liverpool dublin                       False
# 29222  indian                                                  False
# 30715  strappy taquera cdmx tacos                              False
# 11173  tacos                                                   False
# 3590   gemsen aus dem ofen frnda kark sebze trkische gerichte  False
# 17792  oreo churros                                            False
# 36391  trkische fladen kark pideler trkische gerichte          False

# %% [markdown]
# ### Grab only the cleaned titles of the dataframe that are in english

# %%
cleaned = pd.DataFrame(df[df['in_english']==True]['cleaned_title'])

# %%
cleaned.sample(50)
# Out:
#                                                                                                         cleaned_title
# 21454  prime rib sandwich pretzel bun fried egg blue cheese crumbles horseradish cream sauce
# 23910  pancake heart boyfriend
# 3830   vegetable cake bunnies
# 32381  blue collar eats ahi tuna
# 32213  turkey bacon avocado club plus easy egg
# 30665  churros grand mayan tequila chocolate sauce moe cantina chicago
# 30707  fried oysters remoulade
# 30757  prime rib roast yorkshire puddings pleased results
# 38995  sushi bento box
# 13456  thai coconut curried tuna strangewich
# 35897  sweet chili buffalo wings
# 18724  hosted puerto rican brunch revamped leftovers fried rice pork garlic rice sweet plantains egg
# 44758  love mole
# 3266   needed excuse photograph cutting board
# 28484  christmas porchetta pretty pleased result
# 36834  mothers circus animal topped cake
# 17483  chicken parmesan
# 7581   women empower training
# 8311   coconut sour creme marshmallow snowball cake
# 11789  indian vegetarian thali maharaja bhog houston
# 6639   seemed special japanese junk
# 42124  reaction post seaside soft serve
# 38063  tomato cucumber salad easy simple light quick cooking
# 10027  indian snack help bar
# 17504  junk funny say
# 27987  salted caramel chocolate cake
# 5876   gluten chocolate coffee cupcakes
# 30402  carnitas tacos pickled serrano pepper radishes
# 42337  vegan bowl attack grilled romaine chop salad legendary recipes
# 32751  popcorn glitter foodie review wahaca wimbledon
# 42690  gourmet burgers soon navy sailor
# 9995   creamy italian beefaroni casserole
# 41715  dry aged grass fed reverse seared tomahawk seems thing post
# 16400  red velvet white ganache blue berry cake
# 33254  order sloppy joe jersey find ground beef
# 37894  pork bbq lime mustard coleslaw poppy seeds cheddar french toast
# 15401  beef rump celeriac pure baby heritage carrots pickled beetroot red wine jus
# 20543  mardi gras party foods
# 25280  bahubali meals south india comprises dishes one meal non veg taste magic south indian style single serve price
# 21948  ghost milkshake younger sis milkshakoholic p
# 23536  bacon makes everything better double double n even better bring bacon
# 33827  chicken liver pt look mandarin
# 30385  shrimp etouffee girlfriend
# 24182  finally place start meal every tonight thai beef salad
# 37539  ramen min egg unveiling
# 26951  keto friendly stuffed mushrooms bacon
# 31185  fitnessmodel fitfood fitdutchies healthyliving health healthy healtfood fitgirls
# 2187   peanut butter jelly w grapes breakfast
# 13533  tier colour double chocolate cake caramel squashes smarties middle sons
# 27832  fresh fruit vegetable beef fish provider

# %% [markdown]
# ### Pickle the data:

# %%
cleaned.to_pickle('cleaned_data.pkl')
