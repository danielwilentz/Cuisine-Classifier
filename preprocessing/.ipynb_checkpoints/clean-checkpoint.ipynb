# %%
# Imports

import numpy as np
import pandas as pd
import re 
import string
from googletrans import Translator
import nltk
from nltk.corpus import stopwords

# Setting options

pd.set_option('display.max_colwidth', -1)
nltk.download('stopwords')

# Load stop words
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danielwilentz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Read the data
df = pd.read_pickle('../scrape/data/posts.pkl')

# %%
# Take a look!
df = df.rename(columns = {0: 'title'})
df.sample(20)
# Out:
#                                                                                                       title
# 17503  Now thats a calzone. Cleveland, Ohio.(Lime for scale)
# 20554  Pates (Savory &amp; Deli Foods) Market in Saudi Arabia Analytics by Category &amp; Cost Type to 2021
# 16634  how to make friends (with baguette)
# 22894  Annihilation (2018) - Teaser Trailer
# 16638  Tiramisu ! I made it!
# 17855  Chickeeeeeeen and herbs to be grilled
# 10863  Honey drizzled figs from the backyard tree my grand-pappy planted.
# 4468   Some Freezing Cold Brew on a Hot Hot Day [3024 × 4032] [OS]
# 13382  Fun facts to learn about Pineapple for improving your health.
# 5864   Spinach and tomato dinner
# 14393  Brother in law was today’s chef!
# 14321  Ratatouille 🐀
# 16287  [Homemad]Aloo Gobhi Matar Curry (With Extra Punch) . [1280x720][6:47] [ V ]
# 779    Sushi Dragon
# 6023   Funny Sarcastic Distressed Tacos Think about Me Too.... Humors Text Illustration Design
# 19534  We sank this sushi boat last night.
# 1199   Grubbin with Calo- Keezy Bang Bang Bang
# 10425  Filipino Nilgang baka (boiled beef soup) &amp; rice.
# 10265  Melodious Healthy Vegetarian Desi Drink 'Hare Aam Ka Abshola' of India
# 23212  Shakshuka [OC] [640]x[640]

# %%
# Structure analysis
num_words = df[0].apply(lambda x: len(x.split()))
num_words_mean, num_words_std = np.mean(num_words), np.std(num_words)

# %%
print('Mean number of words per post: {} \n STD of words per post: {}'.format(num_words_mean, num_words_std))
# Out:
# Mean number of words per post: 8.72114065180103
#  STD of words per post: 6.399156977264049

# %% [markdown]
# # Define some cleaning functions

# %%
# Function for removing punctuation
def drop_punc(my_text):
    clean_text = re.sub('[%s]' % re.escape(string.punctuation), ' ', my_text)
    return clean_text

# %%
# Function for making it all text lowercase
def lower(my_text):
    clean_text = my_text.lower()
    return clean_text

# %%
# Function for removing all numbers
def remove_numbers(my_text):
    clean_text = re.sub('\w*\d\w*', '', my_text)
    return clean_text

# %%
# Function for removing emojis
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
# Function for removing stop words
def remove_stop(my_text):
    text_list = my_text.split()
    return ' '.join([word for word in text_list if word not in stop_words])

# %%
# Curated list of additional stop-words for this project
my_stop_words = ['oc', 'amp', 'homemade', 'food', 'foodporn', 'v', 'x', 'recipe']

# Function for removing my stop words
def remove_my_stop(my_text):
    text_list = my_text.split()
    return ' '.join([word for word in text_list if word not in my_stop_words])

# %% [markdown]
# ### Special function for removing posts that are ads:

# %%
# curated list for words pertaining to advertisements:
ad_words = ['coupon', 'coupons', 'company', 'companies', 'promo', 'promos', 'code', 'https']
def catch_ads(my_text):
    text_list = my_text.split()
    ad = False
    for word in text_list:
        if word in ad_words:
            ad = True
            break
    if ad: return None
    else: return my_text

# %% [markdown]
# # Let's see how well our functions work!

# %%
test = df.sample(50)

# %%
for index, row in test.iterrows():
    text = row[0]
    print(text)
    cleaned = deEmojify(remove_numbers(drop_punc(lower(text))))
    print(cleaned)
    cleaned_no_punc = remove_my_stop(remove_stop(cleaned))
    print(cleaned_no_punc)
    no_ads = catch_ads(cleaned_no_punc)
    print(no_ads.strip())
    print()
# Out:
# My first go at Chicken and Waffles
# my first go at chicken and waffles
# first go chicken waffles
# first go chicken waffles
#
# smokes spare ribs
# smokes spare ribs
# smokes spare ribs
# smokes spare ribs
#
# "Mount Olympus" at Zeus in Canterbury, lovely veggie meal
#  mount olympus  at zeus in canterbury  lovely veggie meal
# mount olympus zeus canterbury lovely veggie meal
# mount olympus zeus canterbury lovely veggie meal
#
# Kroketten mit Kartoffel und Gouda – Patatesli Kaşarlı Kroket - Türkische Gerichte
# kroketten mit kartoffel und gouda  patatesli kaarl kroket   trkische gerichte
# kroketten mit kartoffel und gouda patatesli kaarl kroket trkische gerichte
# kroketten mit kartoffel und gouda patatesli kaarl kroket trkische gerichte
#
# Is that a cake!? CAKES SPECIALLY MADE FOR THE BAD &amp; BOUJEE. IG: @Dolce_byJess &amp; @yantaamu. Custom Gucci is possible! Anything is Possible!
# is that a cake   cakes specially made for the bad  amp  boujee  ig   dolce byjess  amp   yantaamu  custom gucci is possible  anything is possible
# cake cakes specially made bad boujee ig dolce byjess yantaamu custom gucci possible anything possible
# cake cakes specially made bad boujee ig dolce byjess yantaamu custom gucci possible anything possible
#
# Nutella and almond Christmas tree
# nutella and almond christmas tree
# nutella almond christmas tree
# nutella almond christmas tree
#
# Red Velvet Cheesecake!! Delicious!!
# red velvet cheesecake   delicious
# red velvet cheesecake delicious
# red velvet cheesecake delicious
#
# Avocado honey o miel de aguacate, is one the most famous mexican honeys.
# avocado honey o miel de aguacate  is one the most famous mexican honeys
# avocado honey miel de aguacate one famous mexican honeys
# avocado honey miel de aguacate one famous mexican honeys
#
# Attack of the Killer Tomatoes-6oz beef patty(chuck/shortrib), mozzarella, tomato bacon jam, tomato chutney aioli, fried green tomato, sundried tomatos(rehydrated and marinated) and arugula on a brioche bun
# attack of the killer tomatoes  beef patty chuck shortrib   mozzarella  tomato bacon jam  tomato chutney aioli  fried green tomato  sundried tomatos rehydrated and marinated  and arugula on a brioche bun
# attack killer tomatoes beef patty chuck shortrib mozzarella tomato bacon jam tomato chutney aioli fried green tomato sundried tomatos rehydrated marinated arugula brioche bun
# attack killer tomatoes beef patty chuck shortrib mozzarella tomato bacon jam tomato chutney aioli fried green tomato sundried tomatos rehydrated marinated arugula brioche bun
#
# Homemade Cookie Brownies 😻😻
# homemade cookie brownies
# cookie brownies
# cookie brownies
#
# Microwave Scrambled Quail Eggs [OC][900x1600]
# microwave scrambled quail eggs  oc
# microwave scrambled quail eggs
# microwave scrambled quail eggs
#
# Tomatoes, ready to be roasted
# tomatoes  ready to be roasted
# tomatoes ready roasted
# tomatoes ready roasted
#
# Grilled Octopus with Vegtables
# grilled octopus with vegtables
# grilled octopus vegtables
# grilled octopus vegtables
#
# Sirloin “fork and knife” sandwich.
# %%
df['cleaned_title'] = df['title'].apply(lower).apply(drop_punc).apply(remove_numbers).apply(deEmojify)
df['cleaned_title'] = df['cleaned_title'].apply(remove_stop).apply(remove_my_stop).apply(catch_ads)
df['cleaned_title'] = df['cleaned_title'].str.strip()

# %%
df.sample(50)
# Out:
#                                                                                                                                                                                                                                                                                         title  \
# 11684  SMITH-CELERY SALAD - the recipe is in the ebook that is given for free to anyone who submits the short survey
# 5707   [I ate] Large Doner kebab with broasted potatoes [OC] [1600 × 1200]
# 21625  Un Kurabiyesi Tarifi
# 22349  Happy Apples (1024×768)
# 10308  Tokyo Food Diary &amp; Sushi Eating Show
# 16565  [OC] The perfect charcuterie
# 20953  [Homemade] Peach Caramel Blondie Cheesecake
# 1662   [Homemade] Thai peanut ramen
# 10817  Down 85lbs and keeping it off!
# 21463  Stuffed mushrooms, the top batch has sausage and the bottom batch has crab meat and shrimp
# 10198  Sweets.....
# 5863   Windows Technical Support Number +1-800-449-1424
# 804    Some ribs I smoked for 5 hours yesterday. I got too drunk cooking them and never ate them.
# 4659   Getting ready to enjoy a tasty dinner!
# 5934   Whole, fried, sustainable fish w/ jicama slaw and lentils (Tiffins WDW)
# 6634   Butternut squash kimchi w/ peanuts
# 18454  paratta
# 907    What Jon Made: Gumamela ice cream
# 11164  Pan seared halibut, corn purée, charred grilled broccoli rabe
# 19259  Fresh off the grill (no gas) chicken Jamaica Jamaica Durham NC.
# 16150  Third time baking - my friend made a geode cake!
# 23229  [OC] simple salad with tomatoes, red onions, and carrots with creamy Italian dressing and a side of herbed buttered bread. [3128x2346]
# 3206   Vancouver sells Yummy Duran from Thailand !
# 2299   Christmas Eve roast
# 6934   Some delicious Pho for a beautiful Tuesday
# 21288  When life hands you white cake, berries, and chocolate sauce
# 9804   7/24 SAAT KEBAP SİPARİŞİ - 0212 621 77 32 - AKSARAY, FATİH, KARAKÖY, GALATA,BALAT
# 2108   The best sushi I ever ate
# 22088  Dinner Burgers
# 8844   [Homemade] Red wine braised short ribs with roasted carrot and potato mash
# 16079  Thai Crab Curry by my wife
# 3852   Spaghetti squash.. first time and it was bomb
# 8375   Chicken Chilli, [Homemade], [Chicken Chilli Masala Recipe], [Chicken Chilli Recipe], [Delicious Chicken Chilli Recipe], [Dinner Chicken Chilli Recipe], [Recipe for Chicken Chilli], [Desi Chinese Chicken Chilli Recipe], and [IndoChinese Chicken Chilli Recipe].
# 6336   These really yummy nachos I made! (Also, dont mind the bird)
# 4206   [Homemade] A Smashburger
# 9779   Lamb and Gravy Toasted Sandwiches after a roast
# 12997  Quick lunch I made today
# 2288   [OC] Farfalle pasta beef stroganoff
# 11346  [OC] Mustard &amp; Herb Prime Rib, ill post a picture when it’s done roasting as well.
# 3211   MOD
# 1272   Southwest tater-tot hot dish Minnesotans will be proud.
# 19143  Kurkuma – das stark färbende orange-gelbe Gewürz
# 18152  Delicious Fish Tacos
# 14251  Yam Gravy
# 10895  منيوالاسبوعى للاكلات مع ميزانية أسبوع ومشترياتى أول شعبان بالأسـعار 13 -...
# 21194  brought some dungees up today, thought id treat myself
# 13061  A few wings on the smoker.
# 13351  This is the best fries I ever tried.
# 23115  HEY EVERYONE, My name is Khrisace (Chris•Shay) I AM VERY NEW TO YOUTUBE BUT AM DROPPING MAJOR CONTENT!!! I HAVE COOKING VIDEOS, CHALLENGES, REACTIONS VIDEOS, HOW TOs &amp;&amp; MUCH MUCH MORE!! JOIN THE FAMILY/SUBSCRIBE @Khrisaceb and I'LL KEEP THESE VIDEOS COMING!!!! THANK YOU
# 6633   Perfect Scotch Eggs
#
#                                                                                                                                                                                    cleaned_title
# 11684  smith celery salad ebook given free anyone submits short survey
# 5707   ate large doner kebab broasted potatoes
# 21625  un kurabiyesi tarifi
# 22349  happy apples
# 10308  tokyo diary sushi eating show
# 16565  perfect charcuterie
# 20953  peach caramel blondie cheesecake
# 1662   thai peanut ramen
# 10817  keeping
# 21463  stuffed mushrooms top batch sausage bottom batch crab meat shrimp
# 10198  sweets
# 5863   windows technical support number
# 804    ribs smoked hours yesterday got drunk cooking never ate
# 4659   getting ready enjoy tasty dinner
# 5934   whole fried sustainable fish w jicama slaw lentils tiffins wdw
# 6634   butternut squash kimchi w peanuts
# 18454  paratta
# 907    jon made gumamela ice cream
# 11164  pan seared halibut corn pure charred grilled broccoli rabe
# 19259  fresh grill gas chicken jamaica jamaica durham nc
# 16150  third time baking friend made geode cake
# 23229  simple salad tomatoes red onions carrots creamy italian dressing side herbed buttered bread
# 3206   vancouver sells yummy duran thailand
# 2299   christmas eve roast
# 6934   delicious pho beautiful tuesday
# 21288  life hands white cake berries chocolate sauce
# 9804   saat kebap siparii aksaray fatih karaky galata balat
# 2108   best sushi ever ate
# 22088  dinner burgers
# 8844   red wine braised short ribs roasted carrot potato mash
# 16079  thai crab curry wife
# 3852   spaghetti squash first time bomb
# 8375   chicken chilli chicken chilli masala chicken chilli delicious chicken chilli dinner chicken chilli chicken chilli desi chinese chicken chilli indochinese chicken chilli
# 6336   really yummy nachos made also dont mind bird
# 4206   smashburger
# 9779   lamb gravy toasted sandwiches roast
# 12997  quick lunch made today
# 2288   farfalle pasta beef stroganoff
# 11346  mustard herb prime rib ill post picture done roasting well
# 3211   mod
# 1272   southwest tater tot hot dish minnesotans proud
# 19143  kurkuma das stark frbende orange gelbe gewrz
# 18152  delicious fish tacos
# 14251  yam gravy
# 10895
# 21194  brought dungees today thought id treat
# 13061  wings smoker
# 13351  best fries ever tried
# 23115  hey everyone name khrisace chrisshay new youtube dropping major content cooking videos challenges reactions videos tos much much join family subscribe khrisaceb keep videos coming thank
# 6633   perfect scotch eggs

# %%
test = df.sample(50)

# %%
translator = Translator()

# %%
for index, row in test.iterrows():
    text = row['cleaned_title']
    print('raw: ', text)
    try:
        translated = translator.translate(text, dest='en')
        print('translated: ', translated.text)
    except Exception as e:
        print(str(e))
    print()
# Out:
# fianc crushed tagine benefits north african princess
# fianc crushed tagine benefits north african princess
#
# thanksgiving prepared oldest aunt mother days preparation finished eating minutes quiet minutes
# thanksgiving prepared oldest aunt mother days preparation finished eating minutes quiet minutes
#
# parmigiano bank italy
# parmigiano bank italy
#
# roomate made tomato stew eguse soup fried fish goat skin hen pork topped bitter leaf traditional nigerian seasonings one best thints eaten
# roomate made tomato stew egusi soup fried fish goat skin hen pork topped bitter leaf traditional nigerian seasonings one best things eaten
#
# first time home made pizza
# first time home made pizza
#
# trucks life
# trucks life
#
# barbacoa tacos consome right way eat
# barbacoa tacos consome right way eat
#
# pancake day england naturally decided make raspberry brownies instead
# pancake day england naturally decided make raspberry brownies instead
#
# snowflake dessert patbingsu koreans call
# snowflake dessert patbingsu koreans call
#
# lemon ricotta pancakes smoked salmon served country potato roll
# lemon ricotta pancakes smoked salmon served country potato roll
#
# vampire tacos yard house
# vampire tacos yard house
#
# chesse beacon toast made yr old
# cheese bacon toast made yr old
#
# tres leches cake
# Tres leches cake
#
# wagyu beef sushi
# ぎ え f Sushi
#
# lunches get much better pie mash ale
# lunches get much better pie mash ale
#
# one best burgers town ohmyburger gardena california holeinthswall place
# one best burgers town ohmyburger gardena california holeinthswall place
#
# best nespresso capsules ultimate guide espresso lovers
# best nespresso capsules ultimate guide espresso lovers
#
# yumi
# corn
#
# bread toppings
# bread toppings
#
# vanilla ice cream cherries cooked wine lokys vilnius
# vanilla ice cream cherries cooked wine lokys vilnius
#
# deluxe beef burger w bacon pickles amazing tomato relish wholesome local cafe
# deluxe beef burger w bacon pickles amazing tomato relish wholesome local cafe
#
# nothing like tiramisu
# nothing like tiramisu
#
# hunters chicken
# hunters chicken
#
# made tocino served basmati rice cooked star anise cardamom fried egg
# made tocino served basmati rice cooked star anise cardamom fried egg
#
# first attempt making risotto scallops
# first attempt making risotto scallops
#
# maw maw restaurant worm fiddling burger
# maw maw restaurant worm fiddling burger
#
# cute lol
# cute lol
#
# apple crumb pie vanilla ice cream
# apple crumb pie vanilla ice cream
#
# country fried steak roasted potatoes whiaaaat gravy
# country fried steak roasted potatoes with gravy
#
# four cheese stuffed crust bacon pepperoni pizza
# four cheese stuffed crust bacon pepperoni pizza
#
# ribeye spinach hummus
# ribeye spinach hummus
#
# wife finished making apple pie thanksgiving
# wife finished making apple pie thanksgiving
#
# rice mushrooms ham madeira sauce
# rice mushrooms ham madeira sauce
#
# girl went high school makes ron swanson style bouquets
# girl went high school makes ron swanson style bouquets
#
# fresh pizza
# fresh pizza
#
# double chocolate zucchini cake chocolate ganache
# double chocolate zucchini cake chocolate ganache
#
# sunday cook
# sunday cook
#
# potato cheese onion pierogi
# potato cheese onion pierogi
#
# crab roll
# crab roll
#
# unexpected translation
# unexpected translation
#
# christened new grill succulent salmon filets
# christened new grill succulent salmon fillets
#
# ate real churros con chocolate
# tie real churros with chocolate
#
# husband sent kate weiser chocolates today
# husband sent kate weiser chocolates today
#
# herb crusted salmon angel hair pasta roasted veg
# herb crusted salmon angel hair pasta roasted veg
#
# peanut butter cookies
# peanut butter cookies
#
# seared king salmon cold dragon noodles crab avocado wonton chip nepoleon soy sriracha reduction
# seared king salmon cold dragon noodles crab avocado wonton chip napoleon soy sriracha reduction
#
# fancy steak night
# fancy steak night
#
# delectable turkey
# delectable turkey
#
# spinach ricotta beef empamadas tango truck
# spinach ricotta beef empanadas tango truck
#
# topside beef
# topside beef
